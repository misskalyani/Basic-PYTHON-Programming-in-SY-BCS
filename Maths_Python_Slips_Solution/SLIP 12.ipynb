# %%
Q.1 Attempt any TWO of the following.

# %%
a)write a python program to plot the graph of y = x**3 + 10*x - 5, for x belongs[-10, 10] in red color

# %%
from pylab import *
import numpy as np
x=np.linspace(-10,10,100)
y=x**3+10*x-5
plot(x,y,"--or",label="$x^3+10*x-5$")
xlabel("x")
ylabel("Y")
title("graph of $x^3+10*x-5$")
legend()
show()

# %%
b)write a python program in 3D to rotate the point ( 1, 0, 0) through XZ- plane
in clockwise direction (rotation through Y- axis by an angle of 90°).

# %%
from mpl_toolkits import mplot3d
import numpy as np
from pylab import*
t=np.linspace(10,20,1000)
x=[1]
y=[0]
z=[0]
ax=axes(projection='3d')
ax.scatter(x,y,z,marker='d',color='black')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
title('3d Graph')
show()

# %%
c)Using Python plot the graph of function f(x) = x**2 on the interval (-2,2).

# %%
from pylab import *
import numpy as np
x=np.linspace(-2,2,100)
y=x**2
plot(x,y)
xlabel("x")
ylabel("Y")
title("graph of $x^2")
show()

# %%
Q2)Attempt any TWO of the following.

# %%
a)Write a python program to rotate the segment by 180° having endpoints (1,0)
and (2,-1)

# %%
from sympy import*
s=Segment(Point(1,0),Point(2,-1))
s.rotate(pi)
# Out:
# Segment2D(Point2D(-1, 0), Point2D(-2, 1))

# %%
b)Write a python program to draw a polygon with 8 sides and radius 5 centered
at origin and find its area and perimeter

# %%
p=Polygon((0,0),5,n=8)
print("Area = ",p.area)
print("Perimeter = ",p.perimeter)
# Out:
# Area =  (400 - 200*sqrt(2))/(-4 + 4*sqrt(2))
# Perimeter =  40*sqrt(2 - sqrt(2))

# %%
c)Write a python program to find the area and perimeter of the XYZ, where X(l, 2), Y(2, -2), Z(-1,2).

# %%
from sympy import*
a=Point(1,1)
b=Point(2,-2)
c=Point(1,2)
p=Triangle(a,b,c)
print("Area = ",p.area)
print("Perimeter = ",p.perimeter)
# Out:
# Area =  1/2
# Perimeter =  1 + sqrt(10) + sqrt(17)

# %%
Q3)Attempt the following.

# %%
a)Attempt any ONE of the following.

# %%
i)write a Python program to solve the following LPP
Max Z = 3.5x +2y
Subjected to
x + y >= 5
x >= 4
y <= 2
x>0,y>0

# %%
from pulp import *
model=LpProblem(name="Solution",sense=LpMaximize)
x=LpVariable(name="x",lowBound=0)
y=LpVariable(name="y",lowBound=0)
model += (x+y>=5)
model += (x>=4)
model += (y<=2)
model += 3.5*x+2*y
print(model)
print('\n')
print(model.solve())
print('\nModel Objective Value = ',model.objective.value())
print('\nValue of x = ',x.value())
print('\nValue of y = ',y.value())
# Out:
# Solution:
# MAXIMIZE
# 3.5*x + 2*y + 0.0
# SUBJECT TO
# _C1: x + y >= 5
#
# _C2: x >= 4
#
# _C3: y <= 2
#
# VARIABLES
# x Continuous
# y Continuous
#
#
#
# Welcome to the CBC MILP Solver
# Version: 2.10.7
# Build Date: Feb 14 2022
#
# command line - cbc /tmp/10284272d75a45c99c9b1cab67ca3cd9-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/10284272d75a45c99c9b1cab67ca3cd9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 15 RHS
# At line 19 BOUNDS
# At line 20 ENDATA
# Problem MODEL has 3 rows, 2 columns and 4 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve thinks problem is unbounded
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 8.9999998 (2) Dual inf 5.4999998 (2)
# 0  Obj -0 Primal inf 8.9999998 (2) Dual inf 3e+10 (2)
# 1  Obj 17.5 Dual inf 3.4999999 (1)
# 1  Obj 17.5 Dual inf 3.4999999 (1)
# ...

# %%
ii)Write a python program to display the following LPP by using pulp module
and simplex method. Find its optimal solution if exist.
Min Z = 3x+5y + 4z
subject to
2x+ 3y <= 8
2y + 5z <= 10
3x + 2y + 4z <= 15
x>=0,y>=0,z>=0

# %%
from pulp import*
model=LpProblem(name="Solution",sense=LpMinimize)
x1=LpVariable(name="x1",lowBound=0)
x2=LpVariable(name="x2",lowBound=0)
x3=LpVariable(name="x3",lowBound=0)
model +=(2*x1+3*x2<=24)
model +=(2*x2+5*x3<=15)
model +=(3*x1+2*x2+5*x3<=15)
model +=3*x1+5*x2+4*x3
print(model)
print("\n")
print(model.solve())
print("\n Model Objective value = ",model.objective.value)
print("\nOptimul value Of x1 = ",x1.value())
print("\nOptimul value Of x2 = ",x2.value())
print("\nOptimul value Of x3= ",x3.value())
# Out:
# Solution:
# MINIMIZE
# 3*x1 + 5*x2 + 4*x3 + 0
# SUBJECT TO
# _C1: 2 x1 + 3 x2 <= 24
#
# _C2: 2 x2 + 5 x3 <= 15
#
# _C3: 3 x1 + 2 x2 + 5 x3 <= 15
#
# VARIABLES
# x1 Continuous
# x2 Continuous
# x3 Continuous
#
#
#
# Welcome to the CBC MILP Solver
# Version: 2.10.7
# Build Date: Feb 14 2022
#
# command line - cbc /tmp/0a96a041880b4e19a7c5dfcd1299b3f6-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/0a96a041880b4e19a7c5dfcd1299b3f6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 19 RHS
# At line 23 BOUNDS
# At line 24 ENDATA
# Problem MODEL has 3 rows, 3 columns and 7 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-3) rows, 0 (-3) columns and 0 (-7) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# ...

# %%
b)Attempt any ONE of the following.

# %%
i)Write a python program lo apply the following transformation on the point
(-2, 4)
(I) Reflection through y – axis
(II) Scaling in X – coordinate by 6 factor
(III) Scaling in Y – coordinate by factor 4.1
(IV) Shearing in X Direction by 7/2 units

# %%
from sympy import*
p=Point(-2,4)
print('\nReflection through y – axis = ',p.transform(Matrix([[1,0,0],[0,1,0],[0,0,1]])))
print('\nScaling in X direction = ',p.transform(Matrix([[6,0,0],[0,1,0],[0,0,1]])))
print('\nScaling in Y direction = ',p.transform(Matrix([[1,0,0],[0,4.1,0],[0,0,1]])))
print('\nShearing in Y Direction by 7 unit. = ',p.transform(Matrix([[7/2,1,0],[0,1,0],[0,0,1]])))
# Out:
# Reflection through y – axis =  Point2D(-2, 4)
#
# Scaling in X direction =  Point2D(-12, 4)
#
# Scaling in Y direction =  Point2D(-2, 82/5)
#
# Shearing in Y Direction by 7 unit. =  Point2D(-7, 2)
