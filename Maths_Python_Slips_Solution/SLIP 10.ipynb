# %%
Q.1 Attempt any TWO of the following.

# %%
a)Write a python in 3D to rotate the point (1,0,0) through XY plane in
Clockwise direction (Rotation Through Z – Axis by an angle of 900)

# %%
from mpl_toolkits import mplot3d
from pylab import *
import numpy as np
t=np.linspace(10,20,1000)
x=[1]
y=[0]
z=[0]
ax=axes(projection="3d")
ax.scatter(x,y,z,marker='d',color='black')
ax.set_label('x')
ax.set_label('y')
ax.set_label('z')
title("3D Graph")
show()

# %%
b)Write a Python program to plot 3D line graph Whose parametric equation is
(cos(2x),sin(2x),x) for 10 <= x <= 20 (in red color), with title of the graph

# %%
from mpl_toolkits import mplot3d
from pylab import *
import numpy as np
t=np.linspace(10,20,1000)
x=cos(2*t)
y=sin(2*t)
z=t
ax=axes(projection="3d")
ax.plot(x,y,z,color="red")
title("parametric equation")
show()

# %%
c)Using python, represent the following information using a bar graph (in
green color)
Item        Clothing  Food   Rent  petrol  misc
Expenditure 60        4000   2000  1500    700
in Rs

# %%
from matplotlib.pyplot import *
from numpy import *
items=['Clothing','Food','Rent','Petrol','Misc']
exp=[600,4000,2000,1500,700]
bar(items,exp,width=0.6,color='green')
xlabel('items')
ylabel('Expenditure in Rs')
show()

# %%
Q.2 Attempt any TWO of the following.

# %%
a)Write a python program to rotate the ABC by 90° where A(1, 1), B(2, -2),C(1, 2).

# %%
from sympy import*
a=Point(1,1)
b=Point(2,-2)
c=Point(1,2)
p=Triangle(a,b,c)
p.rotate(90)
# Out:
# Triangle(Point2D(-sin(90) + cos(90), cos(90) + sin(90)), Point2D(2*cos(90) + 2*sin(90), -2*cos(90) + 2*sin(90)), Point2D(-2*sin(90) + cos(90), 2*cos(90) + sin(90)))

# %%
b)Write a Python program to draw a polygon with vertices (0, 0), (2, 0), (2, 3)
and (1, 6) and rotate it by 180° .

# %%
from sympy import*
a=Point(0,0)
b=Point(2,0)
c=Point(2,3)
d=Point(1,6)
p=Polygon(a,b,c,d)
p.rotate(180)
# Out:
# Polygon(Point2D(0, 0), Point2D(2*cos(180), 2*sin(180)), Point2D(2*cos(180) - 3*sin(180), 3*cos(180) + 2*sin(180)), Point2D(cos(180) - 6*sin(180), 6*cos(180) + sin(180)))

# %%
c)Write a Python program to find the area and perimeter of the ABC, where A[0, 0] B[5, 0], C[3,3].

# %%
from sympy import*
a=Point(0,0)
b=Point(5,0)
c=Point(3,3)
p=Triangle(a,b,c)
print("Area = ",p.area)
print("Perimeter = ",p.perimeter)
# Out:
# Area =  15/2
# Perimeter =  sqrt(13) + 3*sqrt(2) + 5

# %%
Q.3)Attempt the following.

# %%
a)Q.1 Attempt any one of the following.

# %%
i)write a Python program to solve the following LPP
Max Z = x + y
Subjected to
x - y >= 1
x + y >= 2
x>0,y>0

# %%
from pulp import *
model=LpProblem(name="Solution",sense=LpMaximize)
x=LpVariable(name="x",lowBound=0)
y=LpVariable(name="y",lowBound=0)
model +=(x - y >= 1)
model +=(x + y >= 2)
model +=x + y
print(model)
print('\n')
print(model.solve())
print('\nModel Objective Value = ',model.objective.value())
print('\nValue of x = ',x.value())
print('\nValue of y = ',y.value())
# Out:
# Solution:
# MAXIMIZE
# 1*x + 1*y + 0
# SUBJECT TO
# _C1: x - y >= 1
#
# _C2: x + y >= 2
#
# VARIABLES
# x Continuous
# y Continuous
#
#
#
# Welcome to the CBC MILP Solver
# Version: 2.10.7
# Build Date: Feb 14 2022
#
# command line - cbc /tmp/2a236a40f0744680aabcd29ca9828593-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/2a236a40f0744680aabcd29ca9828593-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 14 RHS
# At line 17 BOUNDS
# At line 18 ENDATA
# Problem MODEL has 2 rows, 2 columns and 4 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve thinks problem is unbounded
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 2.9999998 (2) Dual inf 1.9999998 (2)
# 1  Obj 2e+10
# 1  Obj 1e+11
# Dual infeasible - objective value 1e+11
# DualInfeasible objective 1e+11 - 1 iterations time 0.012
#
# Result - Linear relaxation unbounded
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# -2
#
# Model Objective Value =  0.0
#
# Value of x =  0.0
#
# Value of y =  0.0

# %%
ii)Write a python program to display the following LPP by using pulp module
and simplex method. Find its optimal solution if exist.
Min Z = 3x+2y + 5z
subject to
x+ 2y + z <= 430
3x + 4z <460
X + 4y <= 120
x>=0,y>=0,z>=0

# %%
from pulp import*
model=LpProblem(name="Solution",sense=LpMinimize)
x1=LpVariable(name="x1",lowBound=0)
x2=LpVariable(name="x2",lowBound=0)
x3=LpVariable(name="x3",lowBound=0)
model +=( x1+2*x2+2*x3 <= 430)
model +=( 3*x1+4*x3<=460)
model +=(x1+4*x2<=120)
model +=3*x1 +2*x2+5*x3
print(model)
print("\n")
print(model.solve())
print("\n Model Objective value = ",model.objective.value)
print("\nOptimul value Of x1 = ",x1.value())
print("\nOptimul value Of x2 = ",x2.value())
print("\nOptimul value Of x3= ",x3.value())
# Out:
# Solution:
# MINIMIZE
# 3*x1 + 2*x2 + 5*x3 + 0
# SUBJECT TO
# _C1: x1 + 2 x2 + 2 x3 <= 430
#
# _C2: 3 x1 + 4 x3 <= 460
#
# _C3: x1 + 4 x2 <= 120
#
# VARIABLES
# x1 Continuous
# x2 Continuous
# x3 Continuous
#
#
#
# Welcome to the CBC MILP Solver
# Version: 2.10.7
# Build Date: Feb 14 2022
#
# command line - cbc /tmp/c3ea1dfa149b4ecbb6134a9ec95dadf6-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/c3ea1dfa149b4ecbb6134a9ec95dadf6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 19 RHS
# At line 23 BOUNDS
# At line 24 ENDATA
# Problem MODEL has 3 rows, 3 columns and 7 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-3) rows, 0 (-3) columns and 0 (-7) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# 1
#
#  Model Objective value =  <bound method LpAffineExpression.value of 3*x1 + 2*x2 + 5*x3 + 0>
#
# Optimul value Of x1 =  0.0
#
# Optimul value Of x2 =  0.0
#
# Optimul value Of x3=  0.0

# %%
b)Attempt any one of the following.

# %%
i)Write a python program lo apply the following transformation on the point
(-2, 4)
(I) Shearing in Y direction by 7 unit
(II) Scaling in X and Y direction by 3/2 and 4 unit respectively.
(III) Shearing in X and Y direction by 2 and 4 unit respectively.
(IV) Rotation About origin by an angle 45o

# %%
from sympy import*
p=Point(-2,4)
print('\nShearing in Y Direction by 7 unit. = ',p.transform(Matrix([[1,7,0],[0,1,0],[0,0,1]])))
print('\nScaling in X  direction = ',p.transform(Matrix([[3/2,0,0],[0,4,0],[0,0,1]])))
print('\nShearing in X & Y Direction by 7 unit. = ',p.transform(Matrix([[0,4,0],[2,0,0],[0,0,1]])))
print("\n Rotation about origin through an angle pi :: ",p.rotate(45))
# Out:
# Shearing in Y Direction by 7 unit. =  Point2D(-2, -10)
#
# Scaling in X  direction =  Point2D(-3, 28)
#
# Shearing in X & Y Direction by 7 unit. =  Point2D(8, -8)
#
#  Rotation about origin through an angle pi ::  Point2D(-4*sin(45) - 2*cos(45), -2*sin(45) + 4*cos(45))
