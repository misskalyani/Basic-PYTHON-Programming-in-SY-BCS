# %%
Q1)Q.1 Attempt any TWO of the following.

# %%
a)Write a python program to plot 3D axes with labels as X – axis and Y – axis
And z axis and also plot following point. With given coordinate in the same graph
(70,-25,15) as a diamond in black color

# %%
from mpl_toolkits import mplot3d
import numpy as np
from pylab import*
t=np.linspace(10,20,1000)
x=[70]
y=[-25]
z=[15]
ax=axes(projection='3d')
ax.scatter(x,y,z,marker='d',color='black')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
title('3d Graph')
show()

# %%
b)Plot the graph of y = e**-x in [-5,5] with red dashed line with Upward
pointing Triangle

# %%
from pylab import *
import numpy as np
x=np.linspace(-5,5,100)
y=e**-x**2
plot(x,y,"--or",label="$e^-x^2$")
xlabel("x")
ylabel("Y")
title("graph of $e^-x^2$")
legend()
show()

# %%
c)Using python, represent the following information using a bar graph (in green color)
Subject    Maths   Science  English   Marathi  Hindi
Percentage  68       90       70        85      91
of passing

# %%
import matplotlib.pyplot as plt
import numpy as np
subject=["maths","science","english","marathi","hindi"]
percentage=[68,90,70,85,91]
plt.bar(subject,percentage,width=0.6,color="green")
plt.xlabel("subject")
plt.ylabel("percentage")
plt.show()

# %%
Q.2)Attempt any TWO of the following.

# %%
a)Write a python program to rotate the ABC by 90° where A(1, 1), B(2, -2), C(1, 2).

# %%
from sympy import*
a=Point(1,1)
b=Point(2,-2)
c=Point(1,2)
p=Triangle(a,b,c)
p.rotate(90)
# Out:
# Triangle(Point2D(-sin(90) + cos(90), cos(90) + sin(90)), Point2D(2*cos(90) + 2*sin(90), -2*cos(90) + 2*sin(90)), Point2D(-2*sin(90) + cos(90), 2*cos(90) + sin(90)))

# %%
b)Write a python program to reflect the ABC through the line y = 3 where A(1,0), B(2, -2), C(-1, 2).

# %%
from sympy import*
x,y=symbols('x y')
a=Point(1,0)
b=Point(2,-2)
c=Point(-1,2)
p=Triangle(a,b,c)
p.reflect(Line(x-y+3))
# Out:
# Triangle(Point2D(-3, 4), Point2D(-5, 5), Point2D(-1, 2))

# %%
c)Write a python program to draw a polygon with 6 sides and radius 1
centered at (1,2) and find its area and perimeter

# %%
p=Polygon((1,2),1,n=6)
print("Area = ",p.area)
print("Perimeter = ",p.perimeter)
# Out:
# Area =  3*sqrt(3)/2
# Perimeter =  6

# %%
Q3)Attempt the following.

# %%
a)Attempt any ONE of the following.

# %%
i)write a Python program to solve the following LPP
Max Z = x + y
Subjected to
x >= 6
y >= 6
x+y >= 11
x>0,y>0

# %%
from pulp import *
model=LpProblem(name="Solution",sense=LpMaximize)
x=LpVariable(name="x",lowBound=0)
y=LpVariable(name="y",lowBound=0)
model += (x>=6)
model += (y>=6)
model += (x+y<=11)
model += x+y
print(model)
print('\n')
print(model.solve())
print('\nModel Objective Value = ',model.objective.value())
print('\nValue of x = ',x.value())
print('\nValue of y = ',y.value())
# Out:
# Solution:
# MAXIMIZE
# 1*x + 1*y + 0
# SUBJECT TO
# _C1: x >= 6
#
# _C2: y >= 6
#
# _C3: x + y <= 11
#
# VARIABLES
# x Continuous
# y Continuous
#
#
#
# Welcome to the CBC MILP Solver
# Version: 2.10.7
# Build Date: Feb 14 2022
#
# command line - cbc /tmp/2af71659f0eb46b9aa1664d85c135cb2-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/2af71659f0eb46b9aa1664d85c135cb2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 15 RHS
# At line 19 BOUNDS
# At line 20 ENDATA
# Problem MODEL has 3 rows, 2 columns and 4 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 12 (2) Dual inf 1.9999998 (2)
# 0  Obj -0 Primal inf 12 (2) Dual inf 2e+10 (2)
# 2  Obj 11 Primal inf 0.9999999 (1)
# Primal infeasible - objective value 11
# ...

# %%
ii)Write a python program to display the following LPP by using pulp module
and simplex method. Find its optimal solution if exist.
Min Z = 3x+5y + 4z
subject to
2x+ 3y <= 8
2y + 5z <= 10
3x + 2y + 4z <= 15
x>=0,y>=0,z>=0

# %%
from pulp import*
model=LpProblem(name="Solution",sense=LpMinimize)
x1=LpVariable(name="x1",lowBound=0)
x2=LpVariable(name="x2",lowBound=0)
x3=LpVariable(name="x3",lowBound=0)
model +=(2*x1+3*x2<=24)
model +=(2*x2+5*x3<=15)
model +=(3*x1+2*x2+5*x3<=15)
model +=3*x1+5*x2+4*x3
print(model)
print("\n")
print(model.solve())
print("\n Model Objective value = ",model.objective.value)
print("\nOptimul value Of x1 = ",x1.value())
print("\nOptimul value Of x2 = ",x2.value())
print("\nOptimul value Of x3= ",x3.value())
# Out:
# Solution:
# MINIMIZE
# 3*x1 + 5*x2 + 4*x3 + 0
# SUBJECT TO
# _C1: 2 x1 + 3 x2 <= 24
#
# _C2: 2 x2 + 5 x3 <= 15
#
# _C3: 3 x1 + 2 x2 + 5 x3 <= 15
#
# VARIABLES
# x1 Continuous
# x2 Continuous
# x3 Continuous
#
#
#
# Welcome to the CBC MILP Solver
# Version: 2.10.7
# Build Date: Feb 14 2022
#
# command line - cbc /tmp/c6d7599c2e804f8d9f0e31d061aa1ed0-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/c6d7599c2e804f8d9f0e31d061aa1ed0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 19 RHS
# At line 23 BOUNDS
# At line 24 ENDATA
# Problem MODEL has 3 rows, 3 columns and 7 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-3) rows, 0 (-3) columns and 0 (-7) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# ...

# %%
b)Attempt any ONE of the following.

# %%
i)Write a python program lo apply the following transformation on the point
(-2, 4)
(I) Shearing in Y direction by 7 units.
(II)Scaling in X and Y direction by 3/2 and 4unit respectively.
(III) Shearing in X and Y direction by 2 and 4 unit respectively.
(IV)Rotation about origin by an angle 45

# %%
from sympy import*
p=Point(-2,4)
print('\nShearing in Y Direction by 7 unit. = ',p.transform(Matrix([[1,7,0],[0,1,0],[0,0,1]])))
print('\nScaling in X  direction = ',p.transform(Matrix([[3/2,0,0],[0,4,0],[0,0,1]])))
print('\nShearing in X & Y Direction by 7 unit. = ',p.transform(Matrix([[0,4,0],[2,0,0],[0,0,1]])))
print("\n Rotation about origin through an angle pi :: ",p.rotate(45))
# Out:
# Shearing in Y Direction by 7 unit. =  Point2D(-2, -10)
#
# Scaling in X  direction =  Point2D(-3, 16)
#
# Shearing in X & Y Direction by 7 unit. =  Point2D(8, -8)
#
#  Rotation about origin through an angle pi ::  Point2D(-4*sin(45) - 2*cos(45), -2*sin(45) + 4*cos(45))
