# %%
Q1)Attempt Any TWO

# %%
a)Write a Python program to plot 2D graph of the functions f(x) = x 2 and g(x)= x3 in [-1, 1]

# %%
from matplotlib.pylab import*
from numpy import *
x=linspace(-1,1,100)
f=x**2
g=x**3
plot(x,f)
plot(x,g)
show()

# %%
b)Write a Python program to plot 3D graph of the function f(x) = e**x**3 in
[-5, 5] with green dashed points line with upward pointing triangle.

# %%
from mpl_toolkits import mplot3d
from numpy import *
from pylab import*
x=linspace(-5,5,100)
y=e**x**3
ax=axes(projection='3d')
ax.plot(x,y,'-.^g')
show()

# %%
c)Write a Python program to generate 3D plot of the functions z = sin x +cos
y in -5< x, y < 5.

# %%
from mpl_toolkits import mplot3d
from numpy import *
from pylab import*
x=linspace(-5,5,100)
y=sin(x)+cos(y)
ax=axes(projection='3d')
ax.plot(x,y,'-.^g')
show()

# %%
Q2)Attempt Any TWO

# %%
(a)write a Python program to reflect the line segment joining the points A[5, 3]
   and B[1, 4] through the line y = x + 1

# %%
from sympy import*
s=Segment(Point(5,3),Point(1,4))
x,y=symbols('x y')
l=Line(x-y+1)
s.reflect(l)
# Out:
# Segment2D(Point2D(2, 6), Point2D(3, 2))

# %%
b)Write a Python program to draw a polygon with vertices (0, 0), (2, 0), (2, 3)
and (1, 6) and rotate it by 180° .

# %%
import matplotlib.pyplot as plt
vertices=[[0,0],[2,0],[2,3],[1,6]]
x=[vertex[0]for vertex in vertices]
y=[vertex[1]for vertex in vertices]
plt.plot(x+[x[0]],y+[y[0]],color="red")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Polygon")
plt.show()

# %%
from sympy import*
from numpy import*
x,y=symbols('x y')
a=Point(0, 0)
b=Point(2, 0)
c=Point(2, 3)
d=Point(1, 6)
p=Polygon(a,b,c,d)
p.rotate(180)
# Out:
# Polygon(Point2D(0, 0), Point2D(2*cos(180), 2*sin(180)), Point2D(2*cos(180) - 3*sin(180), 3*cos(180) + 2*sin(180)), Point2D(cos(180) - 6*sin(180), 6*cos(180) + sin(180)))

# %%
c)Write a Python program to find the area and perimeter of the ABC, where
A[0, 0] B[5, 0], C[3,3].

# %%
from sympy import*
a=Point(0,0)
b=Point(5,0)
c=Point(3,3)
t=Triangle(a,b,c)
print("Area = ",t.area)
print("Perimetr = ",t.perimeter)
# Out:
# Area =  15/2
# Perimetr =  sqrt(13) + 3*sqrt(2) + 5

# %%
Q3 )Attempt the following

# %%
a)Q2)Attempt Any ONE

# %%
i)write a Python program to solve the following LPP
Max Z = 150x + 75y
Subjected to
4x + 6y <= 24
5x + 3y <= 15
x>0,y>0

# %%
from pulp import *
model=LpProblem(name="Solution",sense=LpMaximize)
x=LpVariable(name="x",lowBound=0)
y=LpVariable(name="y",lowBound=0)
model +=(4*x + 6*y >= 24)
model +=(5*x +3*y >= 15)
model +=150*x + 75*y
print(model)
print('\n')
print(model.solve())
print('\nModel Objective Value = ',model.objective.value())
print('\nValue of x = ',x.value())
print('\nValue of y = ',y.value())
# Out:
# Solution:
# MAXIMIZE
# 150*x + 75*y + 0
# SUBJECT TO
# _C1: 4 x + 6 y >= 24
#
# _C2: 5 x + 3 y >= 15
#
# VARIABLES
# x Continuous
# y Continuous
#
#
#
# Welcome to the CBC MILP Solver
# Version: 2.10.7
# Build Date: Feb 14 2022
#
# command line - cbc /tmp/30accb83e47844e480a2c14076c7b809-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/30accb83e47844e480a2c14076c7b809-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 14 RHS
# At line 17 BOUNDS
# At line 18 ENDATA
# Problem MODEL has 2 rows, 2 columns and 4 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve thinks problem is unbounded
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 6.9999998 (2) Dual inf 225 (2)
# Dual infeasible - objective value 2.25e+12
# DualInfeasible objective 2.25e+12 - 0 iterations time 0.012
#
# Result - Linear relaxation unbounded
#
# ...

# %%
ii)Write a python program to display the following LPP by using pulp module
and simplex method. Find its optimal solution if exist.
Min Z = x+y
subject to
x => 6
y => 6
x + y <= 11
x=>0, y=>0

# %%
from pulp import *
model=LpProblem(name="Solution",sense=LpMinimize)
x=LpVariable(name="x",lowBound=0)
y=LpVariable(name="y",lowBound=0)
model +=(x >= 6)
model +=(y >= 6)
model +=(x+y<=11)
model +=x + y
print(model)
print('\n')
print(model.solve())
print('\nModel Objective Value = ',model.objective.value())
print('\nValue of x = ',x.value())
print('\nValue of y = ',y.value())
# Out:
# Solution:
# MINIMIZE
# 1*x + 1*y + 0
# SUBJECT TO
# _C1: x >= 6
#
# _C2: y >= 6
#
# _C3: x + y <= 11
#
# VARIABLES
# x Continuous
# y Continuous
#
#
#
# Welcome to the CBC MILP Solver
# Version: 2.10.7
# Build Date: Feb 14 2022
#
# command line - cbc /tmp/8c2b643fea804ca7a7c0aa20e0ddabe7-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/8c2b643fea804ca7a7c0aa20e0ddabe7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 15 RHS
# At line 19 BOUNDS
# At line 20 ENDATA
# Problem MODEL has 3 rows, 2 columns and 4 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj 0 Primal inf 12 (2)
# 2  Obj 12 Primal inf 0.9999999 (1)
# Primal infeasible - objective value 12
# PrimalInfeasible objective 12 - 2 iterations time 0.002
#
# ...

# %%
b)Attempt Any ONE

# %%
i)Apply each of the following Transformation on the point P[2, -3].
(I)Refection through X-axis.
(II)Scaling in X-co-ordinate by factor 2.
(III) Scaling in Y-co-ordinate by factor 1.5.
(IV) Reflection through the line y = x

# %%
from sympy import*
p=Point(-2,4)
print('\nReflection through x – axis = ',p.transform(Matrix([[1,0,0],[0,-1,0],[0,0,1]])))
print('\nScaling in X direction = ',p.transform(Matrix([[2,0,0],[0,1,0],[0,0,1]])))
print('\nScaling in Y direction = ',p.transform(Matrix([[1,0,0],[0,1.5,0],[0,0,1]])))

print('\nReflection through x y– axis = ',p.transform(Matrix([[-1,0,0],[0,-1,0],[0,0,1]])))
# Out:
# Reflection through x – axis =  Point2D(-2, -4)
#
# Scaling in X direction =  Point2D(-4, 4)
#
# Scaling in Y direction =  Point2D(-2, 6)
#
# Reflection through x y– axis =  Point2D(2, -4)

# %%
ii)Apply each of the following Transformation on the point P[3, -1].
(I) Shearing in Y direction by 2 units.
(II) Scaling in X and Y direction by 1/2 and 3 units respectively.
(III) Shearing in both X and Y direction by -2 and 4 units respectively.
(IV) Rotation about origin by an angle 30 degrees.

# %%
from sympy import*
p=Point(3,-1)
print('\nScaling in X direction = ',p.transform(Matrix([[6,0,0],[0,1,0],[0,0,1]])))
print('\nShearing in Y Direction by 7 unit. = ',p.transform(Matrix([[0,1,0],[1,2,0],[0,0,1]])))
print('\nShearing in X,Y Direction by  unit. = ',p.transform(Matrix([[-2,1,0],[4,0,0],[0,0,1]])))
print("\nRotation about origin by an angle 30 degrees. = ",p.rotate(30))
# Out:
# Scaling in X direction =  Point2D(18, -1)
#
# Shearing in Y Direction by 7 unit. =  Point2D(-1, 1)
#
# Shearing in X,Y Direction by  unit. =  Point2D(-10, 3)
#
# Rotation about origin by an angle 30 degrees. =  Point2D(sin(30) + 3*cos(30), 3*sin(30) - cos(30))
